# %% [markdown]
# #Importing Modules

# %%
import numpy as np
import pandas as pd
import json
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# !pip3 install plotly
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import plotly.express as px

# %%
#____________________

# %%
###Importing The Data

# %%
df_sales = pd.read_csv('Sales_summary_final.csv')
# Out:
# /usr/local/Cellar/jupyterlab/3.0.16_1/libexec/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning:
#
# Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
#____________________

# %% [markdown]
# #Exploratory Data Analysis

# %%
df_sales
# Out:
#                                                     title InvoiceNo StockCode  \
# 0       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1       Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2       Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3               Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
# ...                                                   ...       ...       ...
# 554412  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78579472     71050
# 554413  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78577315     71050
# 554414  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78575941     71050
# 554415  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78573149     71050
# 554416  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78545182     71050
#
# ...

# %%
df_sales.shape
# Out:
# (554417, 16)

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554417 entries, 0 to 554416
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   title         554417 non-null  object
#  1   InvoiceNo     554417 non-null  object
#  2   StockCode     554417 non-null  object
#  3   Quantity      554417 non-null  int64
#  4   InvoiceDate   554417 non-null  object
#  5   CustomerID    415102 non-null  float64
#  6   Country       554417 non-null  object
#  7   url           554417 non-null  object
#  8   rating        554417 non-null  float64
#  9   review_count  554417 non-null  int64
#  10  price         554417 non-null  float64
#  11  product_type  554417 non-null  object
#  12  total_sale    554417 non-null  float64
#  13  ASIN          546019 non-null  object
#  14  invoice_date  554417 non-null  object
#  15  invoice_time  554417 non-null  object
# dtypes: float64(4), int64(2), object(10)
# memory usage: 67.7+ MB

# %%
### Grouping the items by title to compare the sales of the individual products 
### and isolate the top 5 products sold.

# %%
df_sales_title = pd.DataFrame(df_sales.groupby(['title'])['total_sale'].sum())

# %%
df_sales_title
# Out:
#                                                     total_sale
# title
# #1 UbiGear 2 in 1 Universal Car Cell Smartphone...       23.94
# (2020 Latest, Backlit) ANEWISH 2.4GHz Mini Wire...    72247.84
# (2020 Upgraded Ver.) [4CH] Crystal Vision CVT80...   115827.03
# (5 in 1) Miger MacBook Pro 13" Case 2017 & 2016...      274.75
# (Renewed) Acer Flagship CB3-532 15.6 inches HD ...  1086341.00
# ...                                                        ...
# viozon Monitor and Laptop Mount, 2-in-1 Adjusta...    25539.03
# visnfa New Bike Phone Mount Anti Shake and Stab...     5043.95
# wishpower Wireless Mini Keyboard 2.4Ghz Air Mou...   -35284.19
# 【2020 Update Version】 12’’ Screen Magnifier for...     2890.16
# 【Upgraded Version】 YONHAN 4.8A Motorcycle USB C...    17176.89
#
# [4188 rows x 1 columns]

# %%
#Top 5 Products by Sales

# %%
df_sales_title.sort_values(by = "total_sale", ascending = False).head(5)
# Out:
#                                                      total_sale
# title
# Samsung Galaxy S9 G960U 64GB Unlocked 4G LTE Ph...  27327048.60
# Apple iPhone X, 256GB, Silver - Fully Unlocked ...  19288555.00
# Samsung Galaxy S10+ Plus 128GB+8GB RAM SM-G975F...   9271575.00
# Intel Core i7-8700K Desktop Processor 6 Cores u...   9217596.44
# Canon EF 17-40mm f/4L USM Ultra Wide Angle Zoom...   9009418.00

# %%
###

# %%
df_sales.columns
# Out:
# Index(['title', 'InvoiceNo', 'StockCode', 'Quantity', 'InvoiceDate',
#        'CustomerID', 'Country', 'url', 'rating', 'review_count', 'price',
#        'product_type', 'total_sale', 'ASIN', 'invoice_date', 'invoice_time'],
#       dtype='object')

# %%
df_sales_review_cnt = df_sales[['title', 'rating', 'review_count', 'product_type']]

# %%
#which product has the highest rating ?

# %%
df_sales_review_cnt.sort_values(by=['rating', 'review_count'], ascending=False).groupby('title').first().reset_index().sort_values(by=['rating', 'review_count'], ascending=False)
# Out:
#                                                   title  rating  review_count  \
# 317   Adjustable Cell Phone Stand, Lamicall Phone St...     4.9          3436
# 166   AMD Ryzen 9 3900X 12-core, 24-thread unlocked ...     4.9          2088
# 28    12x42 Binoculars for Adults with New Smartphon...     4.9           866
# 3240  Samsung 32GB DDR4 2666MHz RAM Memory Module fo...     4.9           528
# 167   AMD Ryzen 9 3950X 16-Core, 32-Thread Unlocked ...     4.9           475
# ...                                                 ...     ...           ...
# 1094  EVOO  12.5" HD Ultra Slim Laptop, Intel Celero...     2.6           173
# 439   Aquashot Underwater Digital Camera, 26690-RITE...     2.6           102
# 115   4 Pack Smart GPS Tracker Key Finder Locator Wi...     2.4           276
# 3217  STKR Concepts Simple Sucker - Flexible Smartph...     2.3            87
# 3399  Smartphone Projector 2.0, Portable Phone Proje...     2.3            86
#
#      product_type
# ...

# %%
df_sales_review_cnt.sort_values(by=['rating', 'review_count'], ascending=False).head(30)
# Out:
#                                                     title  rating  \
# 421570  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# 421736  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# 422076  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# 422222  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# 423048  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# 423232  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# 423457  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# 423753  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# 423839  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# 423909  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# 424146  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# 424323  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# 424779  Adjustable Cell Phone Stand, Lamicall Phone St...     4.9
# ...

# %%
df_sales_review_cnt = pd.DataFrame(df_sales.groupby(['product_type'])['review_count'].sum())

# %%
df_sales_review_cnt.sort_values(by = "review_count", ascending = False).head(5)
# Out:
#               review_count
# product_type
# smartphone       555725675
# keyboard         393528164
# mouse            384912139
# dslr camera      322088033
# processor        320229295

# %%
#Top rated products

# %%
df_sales_review_cnt.sort_values(by=['review_count'], ascending = True)
# Out:
#               review_count
# product_type
# monitor           34442556
# processor        320229295
# dslr camera      322088033
# mouse            384912139
# keyboard         393528164
# smartphone       555725675

# %%
df_sales_ratings_grouped = df_sales[['title', 'rating', 'review_count', 'price', 'total_sale', 'product_type']]

# %% [markdown]
# Ecommerce Analysis

# %%
df_sales_ratings_grouped.sort_values(by = "review_count", ascending = False).head(20)
# Out:
#                                                     title  rating  \
# 123905  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# 119506  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# 175996  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# 211656  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# 211563  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# 150417  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# 211401  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# 176352  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# 109667  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# 103374  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# 150304  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# 176365  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# 119485  SanDisk Ultra 32GB microSDHC UHS-I Card with A...     4.6
# ...

# %%
df_sales_smartphone = df_sales[df_sales.product_type=="smartphone"]

# %%
df_sales_smartphone.sort_values(by=['total_sale'], ascending=False).groupby('title').first().reset_index().sort_values(by=[ 'total_sale'], ascending=False)
# Out:
#                                                  title InvoiceNo StockCode  \
# 164  CPB Heating Pad Compatible with iPad iPhone Sm...  78581483     23843
# 103  Apple iPhone X, 256GB, Silver - Fully Unlocked...  78550461    85123A
# 693  Samsung Galaxy S9 G960U 64GB Unlocked 4G LTE P...  78546789    85099B
# 904  Xiaomi Redmi Note 8 Pro 64GB, 6GB RAM 6.53" LT...  78562439     84879
# 903  Xiaomi Redmi Note 8 6.3" 64GB 4GB RAM (GSM Onl...  78574294     21915
# ..                                                 ...       ...       ...
# 478  Mini Projector Portable Smart Video Android 7....  78572548     23343
# 234  Collasaro Android Smartwatch, Waterproof Fitne...  78554551    47566B
# 143  Blackview BV5500 pro- Rugged Cell Phone Unlock...  78553391     37370
# 589  Pixel Wireless Lavalier Microphone - Compact W...  78556242     21700
# 615  Power Bank 20000mAh Portable Charger Battery P...  78556687     23003
#
#      Quantity       InvoiceDate  CustomerID Country  \
# ...

# %%
df_sales_smartphone.sort_values(by=['review_count'], ascending=False).groupby('title').first().reset_index().sort_values(by=['rating', 'review_count'], ascending=False)
# Out:
#                                                  title InvoiceNo StockCode  \
# 68   Adjustable Cell Phone Stand, Lamicall Phone St...  78541219     84077
# 8    12x42 Binoculars for Adults with New Smartphon...  78573094     23014
# 91   Amwanan Car Phone Mount, One-Touch Cell Phone ...  78542607     22777
# 69   Adjustable Cell Phone Stand, Lamicall Phone St...  78574074     20914
# 947  iFixit Pro Tech Toolkit - Electronics, Smartph...  78578682     20971
# ..                                                 ...       ...       ...
# 436  Luckies of London Ltd Smartphone Projector, Po...  78578789     23460
# 658  SCORDERS 512 GB Micro SD Card with Adapter (Cl...  78565617     23123
# 28   4 Pack Smart GPS Tracker Key Finder Locator Wi...  78579938     23224
# 669  STKR Concepts Simple Sucker - Flexible Smartph...  78538349    35610A
# 726  Smartphone Projector 2.0, Portable Phone Proje...  78544463    90026D
#
#      Quantity       InvoiceDate  CustomerID Country  \
# ...

# %%
df_sales.product_type.unique()
# Out:
# array(['dslr camera', 'keyboard', 'monitor', 'mouse', 'processor',
#        'smartphone'], dtype=object)

# %%
df_sales_dslr_camera = df_sales[df_sales.product_type=="dslr camera"]

# %%
df_sales_dslr_camera.sort_values(by=['review_count'], ascending=False).groupby('title').first().reset_index().sort_values(by=['rating', 'review_count'], ascending=False)
# Out:
#                                                  title  InvoiceNo StockCode  \
# 211  EN-EL15 EN EL15a Camera Battery Charger Set, Y...   78538566     20818
# 562  Nikon AF-S DX NIKKOR 35mm f/1.8G Lens with Aut...   78571082     22630
# 144  Canon Portrait and Travel Two Lens Kit with 50...   78577519     23321
# 643     Pelican 1510 Case With Padded Dividers (Black)   78578262     23318
# 9    5 Pack - SanDisk Ultra 16GB SD SDHC Memory Fla...   78559359     84947
# ..                                                 ...        ...       ...
# 859  Vivitar DVR785HD-BLU 5MP Pro Waterproof Action...   78580164     23413
# 262  GGS Perfect Foldable LCD Viewfinder 3X Magnifi...   78563467    90179C
# 857  Vivitar 12 MP Digital Camcorder with 4X Digita...   78547005     23177
# 116  Canon BGE2 Battery Grip for the EOS 20D and EO...   78569915    90012A
# 51   Aquashot Underwater Digital Camera, 26690-RITE...   78547362    84858C
#
#      Quantity       InvoiceDate  CustomerID Country  \
# ...

# %%
df_sales_dslr_camera.sort_values(by=['total_sale'], ascending=False).groupby('title').first().reset_index().sort_values(by=[ 'total_sale'], ascending=False)
# Out:
#                                                  title  InvoiceNo StockCode  \
# 120  Canon EF 17-40mm f/4L USM Ultra Wide Angle Zoo...   78561873     84568
# 612  PANASONIC LUMIX G7 4K Mirrorless Camera, with ...   78561397     23122
# 577  Nikon D3500 W/ AF-P DX NIKKOR 18-55mm f/3.5-5....   78566207     21703
# 132  Canon EOS 5D Mark III 22.3 MP Full Frame CMOS ...   78536477     22593
# 569  Nikon AF-S FX NIKKOR 300MM f/4E PF ED Vibratio...   78569463     23268
# ..                                                 ...        ...       ...
# 668  Pixel Wireless Lavalier Microphone - Compact W...   78556242     21700
# 556  Nikon AF-P DX NIKKOR 18-55mm f/3.5-5.6G Lens f...   78569831     20713
# 410  Moza Aircross 2 with Carrying Case, 3-Axis Han...   78553398     37370
# 733  Samsung Electronics EV-NX500ZBMIUS NX500 28 MP...   78576369     21135
# 123  Canon EF 70-200mm f/2.8L IS III USM Lens for C...   78547363     22459
#
#      Quantity       InvoiceDate  CustomerID Country  \
# ...

# %%
df_sales_keyboard = df_sales[df_sales.product_type=="keyboard"]

# %%
df_sales_monitor = df_sales[df_sales.product_type=="monitor"]

# %%
df_sales_keyboard = df_sales[df_sales.product_type=="monitor"]

# %%
df_sales_mouse = df_sales[df_sales.product_type=="mouse"]

# %%
df_sales_processor = df_sales[df_sales.product_type=="processor"]

# %%
#Shopping pattern according to time of the day

# %%
df_time = pd.DataFrame(df_sales.groupby(['invoice_time'])['total_sale'].sum())

# %%
df_time
# Out:
#               total_sale
# invoice_time
# 06:20:00          279.00
# 07:35:00        52776.13
# 07:36:00       269883.64
# 07:37:00        11686.52
# 07:38:00        25879.72
# ...                  ...
# 20:09:00        86555.97
# 20:12:00        28689.72
# 20:13:00        30121.78
# 20:16:00         9765.53
# 20:18:00        17756.66
#
# [742 rows x 1 columns]

# %%
df_time.sort_values(by = "total_sale", ascending = False).head(30)
# Out:
#               total_sale
# invoice_time
# 09:15:00      6586518.84
# 10:01:00      5201667.59
# 11:48:00      4417594.12
# 11:05:00      3461686.30
# 12:03:00      3055577.35
# 11:53:00      3032656.01
# 12:34:00      2918733.30
# 15:04:00      2890233.70
# 11:55:00      2876907.20
# 12:36:00      2690457.38
# 13:37:00      2622208.27
# 10:32:00      2587398.41
# 11:54:00      2568439.29
# 12:11:00      2561021.45
# 15:42:00      2481433.76
# 12:44:00      2458280.07
# 10:47:00      2383324.29
# 13:20:00      2323408.46
# 10:45:00      2321244.29
# 16:12:00      2277484.89
# 13:50:00      2262206.13
# 08:51:00      2223565.01
# 10:52:00      2186631.91
# 12:55:00      2176883.73
# 15:16:00      2153866.28
# 10:41:00      2151773.23
# 12:24:00      2120013.29
# 10:27:00      2111199.14
# 12:59:00      2110987.88
# 13:25:00      2088207.60

# %%
#How do I establish around what time are the most buyers ???

# %%
#_____________

# %%
sns.catplot(y="total_sale", x="product_type", data=df_sales);

# %%
df_sales.Quantity.min()
# Out:
# -9600

# %%
#Analising the buybg pattern by time / Day

# %%
df_sales.InvoiceDate =  pd.to_datetime(df_sales.InvoiceDate )

# %%
df_sales.dtypes
# Out:
# title                   object
# InvoiceNo               object
# StockCode               object
# Quantity                 int64
# InvoiceDate     datetime64[ns]
# CustomerID             float64
# Country                 object
# url                     object
# rating                 float64
# review_count             int64
# price                  float64
# product_type            object
# total_sale             float64
# ASIN                    object
# invoice_date            object
# invoice_time            object
# dtype: object

# %%
df_sales.loc[:,'weekday'] = df_sales.InvoiceDate.dt.weekday

# %%
df_sales.groupby(['weekday']).count()
# Out:
#          title  InvoiceNo  StockCode  Quantity  InvoiceDate  CustomerID  \
# weekday
# 0        81815      81815      81815     81815        81815       59456
# 1        35013      35013      35013     35013        35013       24028
# 2        73048      73048      73048     73048        73048       63851
# 3        88355      88355      88355     88355        88355       62969
# 4        97804      97804      97804     97804        97804       69855
# 5        80069      80069      80069     80069        80069       60389
# 6        98313      98313      98313     98313        98313       74554
#
#          Country    url  rating  review_count  price  product_type  \
# weekday
# 0          81815  81815   81815         81815  81815         81815
# 1          35013  35013   35013         35013  35013         35013
# 2          73048  73048   73048         73048  73048         73048
# 3          88355  88355   88355         88355  88355         88355
# ...

# %%
#Users buy in the morning and around lunchtime
#Monday is the weakest day
#Saturday is the strongest, followed by Thursday, general tendency towards more sales on the weekend

# %%
#Analising the buying pattern by time / Month

# %%
df_sales.loc[:,'month'] = df_sales.InvoiceDate.dt.month

# %%
df_sales.groupby(['month','weekday']).count().head(84)
# Out:
#                title  InvoiceNo  StockCode  Quantity  InvoiceDate  CustomerID  \
# month weekday
# 1     0         5089       5089       5089      5089         5089        3081
#       1         1235       1235       1235      1235         1235        1035
#       2         5356       5356       5356      5356         5356        5039
#       3         7182       7182       7182      7182         7182        3998
#       4         9471       9471       9471      9471         9471        6803
# ...              ...        ...        ...       ...          ...         ...
# 12    2         3222       3222       3222      3222         3222        3157
#       3         6126       6126       6126      6126         6126        4012
#       4         4821       4821       4821      4821         4821        3211
#       5         3364       3364       3364      3364         3364        2329
#       6         5833       5833       5833      5833         5833        3756
#
# ...

# %%
#Analising the buying pattern by custommer

# %%
df_custommer= pd.DataFrame(df_sales.groupby(['CustomerID'])['total_sale'].sum())

# %%
df_custommer
# Out:
#             total_sale
# CustomerID
# 12346.0     4433604.10
# 12347.0      215171.57
# 12348.0      174939.60
# 12349.0       42300.23
# 12350.0       18345.68
# ...                ...
# 18280.0        7094.42
# 18281.0        2713.22
# 18282.0        3304.10
# 18283.0      113308.11
# 18287.0      119910.44
#
# [4339 rows x 1 columns]

# %%
df_custommer.total_sale.max()   ####
# Out:
# 21664738.3

# %%
df_custommer.total_sale.min()
# Out:
# 13.98

# %%
# The biggest Customer is from the Netherlands

df_sales.loc[df_sales['CustomerID'] == 12347.0,  : ]
# Out:
#                                                     title InvoiceNo StockCode  \
# 1292    AmazonBasics High-Speed Mini-HDMI to HDMI TV A...  78581180     20719
# 1293    TARION Pro 2 Bags in 1 Camera Backpack Large w...  78581180     23508
# 21052   Saramonic SR-XM1 3.5mm TRS Omnidirectional Mic...  78573511     21636
# 21053   AmazonBasics Backpack for SLR/DSLR Camera and ...  78573511     22697
# 21054   Vivitar 12 MP Digital Camcorder with 4X Digita...  78573511     23177
# ...                                                   ...       ...       ...
# 550561  Syncwire Long Aux Cable 6.5Ft- Auxiliary Audio...  78537626     22727
# 550562  Plantronics 88120-41 M165 Marque 2 Ultralight ...  78537626     22728
# 550563  Moto G Stylus | Unlocked | Made for US by Moto...  78537626    85167B
# 550564  Gaming Headset for Xbox One, PS4, Nintendo Swi...  78537626     84969
# 550565  Gear Beast Universal Cell Phone Lanyard Compat...  78537626    84997D
#
# ...

# %%
df_sales.loc[df_sales['CustomerID'] == 12348.0,  : ]
# Out:
#                                                     title InvoiceNo StockCode  \
# 84124   Canon EF-S 55-250mm f/4-5.6 IS STM Telephoto Z...  78541998     21985
# 84125   MegaGear ''Ultra Light'' Neoprene Camera Case ...  78541998     21726
# 84126   Neewer Professional Sling Camera Storage Bag D...  78541998     21983
# 90304   AmazonBasics Holster Camera Case for DSLR Came...  78539318     84991
# 90305   AmazonBasics Holster Camera Case for DSLR Came...  78539318     84991
# 90306   Unique Design Lens Cap Bundle, 3 Pcs 52mm Cent...  78539318     21982
# 140331  Perixx Periboard-512 Ergonomic Split Keyboard ...  78568172     23077
# 140332  Kensington Microsoft Surface Pro Rugged Case f...  78568172     23078
# 188394  Perixx Periboard-512 Ergonomic Split Keyboard ...  78548955     23077
# 188395  Kensington Microsoft Surface Pro Rugged Case f...  78548955     23078
# 188396  Cheliz Keyboard Wrist Rest Pad and Mouse Wrist...  78548955     23076
# ...

# %%
# The second biggest Customer is from the Ireland

df_sales.loc[df_sales['CustomerID'] == 14646.0,  : ]
# Out:
#                                                     title InvoiceNo StockCode  \
# 771     AmazonBasics UV Protection Camera Lens Filter ...  78581338     23344
# 1301    MOUNTDOG Photography Continuous Softbox Lighti...  78581176     22712
# 1302    Movo Photo NS-1 Shock-Absorbing Padded Neopren...  78581175     23281
# 1303    Peacechaos Men's Canvas Camera Bag Leather DSL...  78581175     23498
# 1304    Neewer NW565EX E-TTL Slave Flash Speedlite wit...  78581175     22483
# ...                                                   ...       ...       ...
# 544978  Samsung Galaxy Watch smartwatch (46mm, GPS, Bl...  78539491     22720
# 544979  Samsung Galaxy S6 Edge, Black Sapphire 32GB (A...  78539491     22613
# 544980  Phone Tripod LINKCOOL 360 Degree Rotation Flex...  78539491     20751
# 544981  NETGEAR Nighthawk Smart WiFi Router (R6700) - ...  78539491     22960
# 544982  aceyoon Phone Ring Cat Attachable Kickstand Ul...  78539491     22315
#
# ...

# %%
#Analising the buybg pattern by country

# %%
df_sales_country = pd.DataFrame(df_sales.groupby(['Country'])['total_sale'].sum())

# %%
#Top 5 Countries generating max revenue

# %%
df_top_countries = df_sales_country.sort_values(by = "total_sale", ascending = False).head(7).reset_index()

# %%
df_topfive = df_top_countries[1:6]

# %%
sns.catplot(data=df_topfive, x="Country", y="total_sale")

# %%
ax = sns.barplot(x=df_topfive["Country"], y=df_topfive["total_sale"], color = 'steelblue')

# %%
fig = px.bar(df_topfive, x='Country', y='total_sale')
fig.show()
# Out:
# <div>                            <div id="4ad2ecef-c84d-4375-b76d-5858d4220480" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ad2ecef-c84d-4375-b76d-5858d4220480")) {                    Plotly.newPlot(                        "4ad2ecef-c84d-4375-b76d-5858d4220480",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>total_sale=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["Netherlands","Ireland","France","UK","Australia"],"xaxis":"x","y":[22002641.59,15887872.16,11554196.46,11392570.92,9848728.98],"yaxis":"y"}],                        {"barmode":"relative","legend":{"trace
# ...

# %%
df_sales
# Out:
#                                                     title InvoiceNo StockCode  \
# 0       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1       Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2       Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3               Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
# ...                                                   ...       ...       ...
# 554412  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78579472     71050
# 554413  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78577315     71050
# 554414  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78575941     71050
# 554415  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78573149     71050
# 554416  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78545182     71050
#
# ...

# %%
plt.tight_layout()
plt.title('')
sns.barplot(x = "month", y = "total_sale", data = df_sales, color = 'steelblue')
# Out:
# <AxesSubplot:xlabel='month', ylabel='total_sale'>

# %%
#fig_weekday = px.bar(df_sales, x='weekday', y='total_sale')
#fig_weekday.show()

# %%
#fig_months = px.bar(df_sales, x='month', y='total_sale')
#fig_months.show()

# %%
sns.countplot(x = 'weekday', data=df_sales, color = 'steelblue'  )
# Out:
# <AxesSubplot:xlabel='weekday', ylabel='count'>

# %%
plt.tight_layout()
plt.title('')
sns.barplot(x = "invoice_date", y = "total_sale", data = df_sales)
# Out:
# <AxesSubplot:xlabel='invoice_date', ylabel='total_sale'>

# %% [markdown]
# # KPIs

# %%
#1. Total Sale Revenue
df_sales.total_sale.sum()
# Out:
# 586828693.5

# %%
#2.average order value = total sale revenue / number of orders

586828693.5 / 28186
# Out:
# 20819.86424111261

# %%
#Total Nr. of unique invoices

# %%
len(set(df_sales.InvoiceNo))
# Out:
# 28186

# %%
#Repeat purchase rate = purchase from repeat custommer / number of orders ?

# %%
#Total number of orders
df_sales.total_sale.count()
# Out:
# 554417

# %%
#Number of unique custommers 
df_sales.CustomerID.count()
# Out:
# 415102

# %%
len(set(df_sales.CustomerID))
# Out:
# 143654

# %%
len(df_sales.CustomerID.unique())
# Out:
# 4340

# %%
df_sales.isnull().sum()
# Out:
# title                0
# InvoiceNo            0
# StockCode            0
# Quantity             0
# InvoiceDate          0
# CustomerID      139315
# Country              0
# url                  0
# rating               0
# review_count         0
# price                0
# product_type         0
# total_sale           0
# ASIN              8398
# invoice_date         0
# invoice_time         0
# weekday              0
# month                0
# Year                 0
# dtype: int64

# %%
#Purchase Frequency = Total number of orders / Number of unique custommers 
28186 / 4340
# Out:
# 6.49447004608295

# %%
# How do we define a repeat customer? Someone who has more than one order?

# %%
df_sales.InvoiceNo
# Out:
# 0         78581587
# 1         78581587
# 2         78581586
# 3         78581586
# 4         78581585
#             ...
# 554412    78579472
# 554413    78577315
# 554414    78575941
# 554415    78573149
# 554416    78545182
# Name: InvoiceNo, Length: 554417, dtype: object

# %%
df_sales.invoice_date.head(10000)
# Out:
# 0       2019-12-09
# 1       2019-12-09
# 2       2019-12-09
# 3       2019-12-09
# 4       2019-12-09
#            ...
# 9995    2019-11-21
# 9996    2019-11-21
# 9997    2019-11-21
# 9998    2019-11-21
# 9999    2019-11-21
# Name: invoice_date, Length: 10000, dtype: object

# %%
df_sales.invoice_date.max()
# Out:
# '2019-12-09'

# %%
revenue_2018  = df_sales[df_sales.invoice_date=="2018"]

# %%
revenue_2018
# Out:
# Empty DataFrame
# Columns: [title, InvoiceNo, StockCode, Quantity, InvoiceDate, CustomerID, Country, url, rating, review_count, price, product_type, total_sale, ASIN, invoice_date, invoice_time, weekday, month]
# Index: []

# %%
df_sales['invoice_date'] = pd.to_datetime(df_sales['invoice_date'])

# %%
df_sales['Year'] = df_sales['invoice_date'].dt.year

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554417 entries, 0 to 554416
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   title         554417 non-null  object
#  1   InvoiceNo     554417 non-null  object
#  2   StockCode     554417 non-null  object
#  3   Quantity      554417 non-null  int64
#  4   InvoiceDate   554417 non-null  datetime64[ns]
#  5   CustomerID    415102 non-null  float64
#  6   Country       554417 non-null  object
#  7   url           554417 non-null  object
#  8   rating        554417 non-null  float64
#  9   review_count  554417 non-null  int64
#  10  price         554417 non-null  float64
#  11  product_type  554417 non-null  object
#  12  total_sale    554417 non-null  float64
#  13  ASIN          546019 non-null  object
#  14  invoice_date  554417 non-null  datetime64[ns]
#  15  invoice_time  554417 non-null  object
#  16  weekday       554417 non-null  int64
# ...

# %%
df_sales.Year.unique()
# Out:
# array([2019, 2018])

# %%
orders_2018 = df_sales[df_sales.Year == 2018]

# %%
df_sales['weekday'] = df_sales['invoice_date'].dt.weekday

# %%
df_sales
# Out:
#                                                     title InvoiceNo StockCode  \
# 0       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1       Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2       Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3               Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
# ...                                                   ...       ...       ...
# 554412  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78579472     71050
# 554413  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78577315     71050
# 554414  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78575941     71050
# 554415  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78573149     71050
# 554416  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78545182     71050
#
# ...

# %%
orders_2018
# Out:
#                                                     title InvoiceNo StockCode  \
# 88882   BOYA BY-MM1 Shotgun Video Microphone, Universa...  78539992     21470
# 88883                        AmazonBasics 67-Inch Monopod  78539992     21155
# 88884   Neewer Rubber-Coated Metal Camera Lens Filter ...  78539991     21629
# 88885   Estarer Camera Shoulder Bag for SLR/DSLR Digit...  78539991     35443
# 88886   Ring Light with Remote Controller and Stand ip...  78539991     21618
# ...                                                   ...       ...       ...
# 554405  Android Smart Watch for Women Men, 2020 Blueto...  78537160     21811
# 554406  Android Smart Watch for Women Men, 2020 Blueto...  78536572     21811
# 554407  Android Smart Watch for Women Men, 2020 Blueto...  78536569     21811
# 554408  Android Smart Watch for Women Men, 2020 Blueto...  78536544     21811
# 554409  Android Smart Watch for Women Men, 2020 Blueto...  78536409     21811
#
# ...

# %%
revenue_2018 = orders_2018.total_sale.sum()

# %%
revenue_2018
# Out:
# 40310450.64

# %%
orders_2019 = df_sales[df_sales.Year == 2019]

# %%
revenue_2019 = orders_2019.total_sale.sum()

# %%
revenue_2019
# Out:
# 546518242.8599999

# %%
orders_2018
# Out:
#                                                     title InvoiceNo StockCode  \
# 88882   BOYA BY-MM1 Shotgun Video Microphone, Universa...  78539992     21470
# 88883                        AmazonBasics 67-Inch Monopod  78539992     21155
# 88884   Neewer Rubber-Coated Metal Camera Lens Filter ...  78539991     21629
# 88885   Estarer Camera Shoulder Bag for SLR/DSLR Digit...  78539991     35443
# 88886   Ring Light with Remote Controller and Stand ip...  78539991     21618
# ...                                                   ...       ...       ...
# 554405  Android Smart Watch for Women Men, 2020 Blueto...  78537160     21811
# 554406  Android Smart Watch for Women Men, 2020 Blueto...  78536572     21811
# 554407  Android Smart Watch for Women Men, 2020 Blueto...  78536569     21811
# 554408  Android Smart Watch for Women Men, 2020 Blueto...  78536544     21811
# 554409  Android Smart Watch for Women Men, 2020 Blueto...  78536409     21811
#
# ...

# %%
#Calculate Purchase Frequency
#Monthly distribution
#Average order Value
